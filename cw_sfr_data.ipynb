# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('cw_data2.csv')
df
# Out:
#     CASE_NUMBER  CA_OBJECT_ID                             NAME  ROLE_ID  \
# 0     RES17-407           153                     Mikel F Long        1
# 1     RES17-411           157                      Eddie Coats        1
# 2     RES17-418           164                   Adam Schroeder        1
# 3     RES17-419           165          Bass Built Custom Homes        1
# 4     RES18-003           169                     NCA Builders        1
# ..          ...           ...                              ...      ...
# 165   RES20-519          2185        2x4 Designs dba 2x4 Build        1
# 166   RES20-524          2189                       Mike Mason        1
# 167   RES20-528          2193                     Quinn Marlow        1
# 168   RES20-541          2206             Coats Contracting Co        1
# 169   RES20-546          2211  Pat Talbert Building & Dev. LLC        1
#
#                                                   Type            LOCATION  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CASE_NUMBER   170 non-null    object
#  1   CA_OBJECT_ID  170 non-null    int64
#  2   NAME          170 non-null    object
#  3   ROLE_ID       170 non-null    int64
#  4   Type          170 non-null    object
#  5   LOCATION      170 non-null    object
#  6   Permit Fee    170 non-null    float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 9.4+ KB

# %%
df.describe()
# Out:
#        CA_OBJECT_ID  ROLE_ID    Permit Fee
# count    170.000000    170.0    170.000000
# mean     999.488235      1.0  11450.055647
# std      672.484973      0.0   4372.071375
# min      153.000000      1.0   2140.800000
# 25%      360.750000      1.0   8707.875000
# 50%      846.500000      1.0  11808.850000
# 75%     1614.250000      1.0  14081.765000
# max     2211.000000      1.0  22684.600000

# %%
df.NAME.value_counts()
# Out:
# Linwood Chadwick Shingleton    9
# Richard Wallace                8
# Chad Shingleton                7
# Keith Bloemendaal              7
# Kilon Wilson                   7
#                               ..
# H. Glenn Sanderson             1
# AW Homes, Inc                  1
# NCA Builders                   1
# Mikel F Long                   1
# Samm Jernigan                  1
# Name: NAME, Length: 78, dtype: int64

# %%
df.NAME.value_counts().plot(kind='bar');

# %%
df.NAME.duplicated().value_counts()
# Out:
# True     92
# False    78
# Name: NAME, dtype: int64

# %%
df.query('NAME.str.contains("Long")', engine='python')
# Out:
#     CASE_NUMBER  CA_OBJECT_ID                       NAME  ROLE_ID  \
# 0     RES17-407           153               Mikel F Long        1
# 121   RES19-726          1482  MB Long Construction, LLC        1
#
#                                                   Type            LOCATION  \
# 0    Residential Single Family - New Construction -...  1613 Mackerel Lane
# 121  Residential Single Family - New Construction  ...   401 TENNESSEE AVE
#
#      Permit Fee
# 0        7215.4
# 121     10983.8

# %%
df.query('NAME.str.contains("Mike")', engine='python')
# Out:
#     CASE_NUMBER  CA_OBJECT_ID            NAME  ROLE_ID  \
# 0     RES17-407           153    Mikel F Long        1
# 25    RES18-077           243  Mike Poziombka        1
# 56    RES18-330           496  Mike Poziombka        1
# 166   RES20-524          2189      Mike Mason        1
#
#                                                   Type            LOCATION  \
# 0    Residential Single Family - New Construction -...  1613 Mackerel Lane
# 25        Residential Single Family - New Construction     1227 CROAKER LN
# 56        Residential Single Family - New Construction      408 OCEANA WAY
# 166  Residential Single Family - New Construction *...        505 LEWIS DR
#
#      Permit Fee
# 0        7215.4
# 25       3375.4
# 56      10619.2
# 166      2145.8

# %%
df.query('NAME.str.contains("Bass")', engine='python')
# Out:
#     CASE_NUMBER  CA_OBJECT_ID                     NAME  ROLE_ID  \
# 3     RES17-419           165  Bass Built Custom Homes        1
# 16    RES18-045           211              Bryant Bass        1
# 30    RES18-100           266              Bryant Bass        1
# 45    RES18-221           387              Bryant Bass        1
# 58    RES18-333           499              Bryant Bass        1
# 59    RES18-334           500              Bryant Bass        1
# 70    RES18-484           650              Bryant Bass        1
# 79    RES19-034           756          Bass Homes, Inc        1
# 110   RES19-571          1319          Bass Homes, Inc        1
# 150   RES20-301          1952          Bass Homes, Inc        1
# 156   RES20-410          2065          Bass Homes, Inc        1
#
#                                                   Type  \
# 3    Residential Single Family - New Construction s...
# 16        Residential Single Family - New Construction
# ...

# %%
df.query("NAME.str.contains('Covington') or NAME.str.contains('Pioneer')", engine='python')
# Out:
#     CASE_NUMBER  CA_OBJECT_ID                      NAME  ROLE_ID  \
# 10    RES18-028           194      Stephannie Covington        1
# 67    RES18-471           637      Stephannie Covington        1
# 103   RES19-478          1222      Stephannie Covington        1
# 125   RES19-796          1557      Stephannie Covington        1
# 141   RES20-200          1847  The Pioneer Group NC Inc        1
#
#                                                   Type              LOCATION  \
# 10   Residential Single Family - New Construction -...        1622 BOWFIN LN
# 67   Residential Single Family - New Construction -...  702 FAYETTEVILLE AVE
# 103       Residential Single Family - New Construction       605 ATLANTA AVE
# 125  Residential Single Family - New Construction  ...       807 ATLANTA AVE
# 141  Residential Single Family - New Construction  ...           504 KEYS LN
#
#      Permit Fee
# 10      11400.8
# 67      13118.5
# 103     16278.5
# 125      5747.4
# 141      8222.8

# %%
df.query("NAME.str.contains('Chad')", engine='python')
# Out:
#     CASE_NUMBER  CA_OBJECT_ID                         NAME  ROLE_ID  \
# 17    RES18-046           212  Linwood Chadwick Shingleton        1
# 37    RES18-172           338  Linwood Chadwick Shingleton        1
# 38    RES18-173           339  Linwood Chadwick Shingleton        1
# 39    RES18-174           340  Linwood Chadwick Shingleton        1
# 72    RES18-496           662            L Chad Shingleton        1
# 84    RES19-118           839  Linwood Chadwick Shingleton        1
# 94    RES19-324          1060  Linwood Chadwick Shingleton        1
# 95    RES19-325          1061  Linwood Chadwick Shingleton        1
# 104   RES19-509          1255  Linwood Chadwick Shingleton        1
# 114   RES19-618          1366  Linwood Chadwick Shingleton        1
# 119   RES19-712          1467              Chad Shingleton        1
# 130   RES20-020          1650              Chad Shingleton        1
# 131   RES20-021          1651              Chad Shingleton        1
# ...

# %%
df.query("NAME.str.contains('Wells') or NAME.str.contains('Kimberly')", engine='python')
# Out:
#     CASE_NUMBER  CA_OBJECT_ID                     NAME  ROLE_ID  \
# 13    RES18-032           198          Kimberly Garner        1
# 73    RES18-503           669          Kimberly Garner        1
# 78    RES18-548           714          Kimberly Garner        1
# 86    RES19-172           903          Kimberly Garner        1
# 93    RES19-313          1049          Kimberly Garner        1
# 105   RES19-511          1257          Kimberly Garner        1
# 122   RES19-727          1484  Wells Construction Corp        1
# 142   RES20-201          1848  Wells Construction Corp        1
# 143   RES20-243          1890  Wells Construction Corp        1
# 153   RES20-394          2049  Wells Construction Corp        1
#
#                                                   Type  \
# 13   Residential Single Family - New Construction-s...
# 73   Residential Single Family - New Construction -...
# 78      Residential Single Family - New Construction -
# ...

# %%
df.query("NAME.str.contains('Keith') or NAME.str.contains('Dutch')", engine='python')
# Out:
#     CASE_NUMBER  CA_OBJECT_ID               NAME  ROLE_ID  \
# 22    RES18-057           223  Keith Bloemendaal        1
# 27    RES18-089           255  Keith Bloemendaal        1
# 35    RES18-129           295  Keith Bloemendaal        1
# 51    RES18-301           467      Keith Carroll        1
# 54    RES18-320           486  Keith Bloemendaal        1
# 81    RES19-087           809      Keith Carroll        1
# 82    RES19-094           815      Keith Carroll        1
# 87    RES19-183           914  Keith Bloemendaal        1
# 96    RES19-339          1075      Keith Carroll        1
# 97    RES19-349          1086  Keith Bloemendaal        1
# 98    RES19-351          1088  Keith Bloemendaal        1
# 128   RES20-003          1633  Keith Bloemandaal        1
# 129   RES20-004          1634      Keith Carroll        1
#
#                                                   Type  \
# 22        Residential Single Family - New Construction
# ...

# %%
df.query("NAME.str.contains('Piper') or NAME.str.contains('Kimberly')", engine='python')
# Out:
#     CASE_NUMBER  CA_OBJECT_ID             NAME  ROLE_ID  \
# 13    RES18-032           198  Kimberly Garner        1
# 19    RES18-048           214       Todd Piper        1
# 73    RES18-503           669  Kimberly Garner        1
# 76    RES18-540           706       Todd Piper        1
# 78    RES18-548           714  Kimberly Garner        1
# 86    RES19-172           903  Kimberly Garner        1
# 93    RES19-313          1049  Kimberly Garner        1
# 105   RES19-511          1257  Kimberly Garner        1
#
#                                                   Type  \
# 13   Residential Single Family - New Construction-s...
# 19        Residential Single Family - New Construction
# 73   Residential Single Family - New Construction -...
# 76   Residential Single Family - New Construction  ...
# 78      Residential Single Family - New Construction -
# 86        Residential Single Family - New Construction
# 93   Residential Single Family - New Construction  ...
# ...

# %%
inconsistent = df.LOCATION.str.isupper().value_counts()
inconsistent
# Out:
# True     162
# False      8
# Name: LOCATION, dtype: int64

# %% [markdown]
# # Data Assessment
#
# ## Identify Quality and Tidiness issues with the Dataset

# %% [markdown]
# ### Data Quality Issues
# #### `cw_data2` table
# - Contractor Bass is listed with three different names (11)
# - Contractor Long is listed with two different names (2)
# - Stephanie Covington and Pioneer group are the same person (5)
# - Chad Shingleton is listed with three different names (17)
# - Row 119 RES19-712 location is not all upper
# - Row 35 RES18-129 location is not all upper
# - Row 0 RES17-407 location is not all upper
# - CA_OBJECT_ID and ROLE_ID are not integers
# - Kimberly Garner and Wells Construction are the same person (10)

# %% [markdown]
# ### Data Tidiness Issues
# #### `cw_data2` table
# - Column formatting isinconsistent
# - Column NAME type contains more data than one column
