# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
columns = ['permit_number', 'project_id', 'person', 'person_id', 'fees', 'type', 'address']
df = pd.read_csv('cw_data.csv', sep=',', names=columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10614 entries, 0 to 10613
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   permit_number  10614 non-null  object
#  1   project_id     10614 non-null  int64
#  2   person         10612 non-null  object
#  3   person_id      10612 non-null  float64
#  4   fees           6918 non-null   float64
#  5   type           10614 non-null  object
#  6   address        10614 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 580.6+ KB

# %%
df.project_id = df.project_id.astype(str)
df.person_id = df.person_id.astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10614 entries, 0 to 10613
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   permit_number  10614 non-null  object
#  1   project_id     10614 non-null  object
#  2   person         10612 non-null  object
#  3   person_id      10614 non-null  object
#  4   fees           6918 non-null   float64
#  5   type           10614 non-null  object
#  6   address        10614 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 580.6+ KB

# %%
df.describe()
# Out:
#               fees
# count  6918.000000
# mean    966.358034
# std    1277.329919
# min       0.000000
# 25%     150.000000
# 50%     250.000000
# 75%    2000.000000
# max    9415.500000

# %%
df.head(30)
# Out:
#    permit_number project_id        person person_id    fees  \
# 0      RES17-407        153  Mikel F Long         6    10.0
# 1      RES17-407        153  Mikel F Long         1    10.0
# 2      RES17-407        153     mike Long         8    10.0
# 3      RES17-407        153  Mikel F Long         6   250.0
# 4      RES17-407        153  Mikel F Long         1   250.0
# 5      RES17-407        153     mike Long         8   250.0
# 6      RES17-407        153  Mikel F Long         6  2159.4
# 7      RES17-407        153  Mikel F Long         1  2159.4
# 8      RES17-407        153     mike Long         8  2159.4
# 9      RES17-407        153  Mikel F Long         6   250.0
# 10     RES17-407        153  Mikel F Long         1   250.0
# 11     RES17-407        153     mike Long         8   250.0
# 12     RES17-407        153  Mikel F Long         6     0.0
# 13     RES17-407        153  Mikel F Long         1     0.0
# 14     RES17-407        153     mike Long         8     0.0
# ...

# %%
df.person_id = df.person_id.str.rstrip('.0')
df.head(2)
# Out:
#   permit_number project_id        person person_id  fees  \
# 0     RES17-407        153  Mikel F Long         6  10.0
# 1     RES17-407        153  Mikel F Long         1  10.0
#
#                                                 type             address
# 0  Residential Single Family - New Construction -...  1613 Mackerel Lane
# 1  Residential Single Family - New Construction -...  1613 Mackerel Lane

# %%
test = df.groupby('permit_number').sum()
test.hist();
test.median()
# Out:
# fees    36613.65
# dtype: float64

# %%
df.person_id.value_counts()
# Out:
# 8      3148
# 6      3060
# 1      3060
# 13      715
# 7       629
# nan       2
# Name: person_id, dtype: int64

# %%
df.query("project_id = '153'")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-6c2eef1d080d> in <module>
# ----> 1 df.query("project_id = '153'")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# ...
